# %% [markdown]
# # Multi Class Logistic Regression
#
#
# ## Dataset
# Data sourced from `security_data_10000.csv` (synthetic data generated from original class dataset).
#
# | Column | Description |
# |--------|-------------|
# | Sector | Industry sector of the company |
# | CEO_Gender | Gender of the CEO (Male/Female) |
# | Size | Company size (Large, Medium, Small) |
# | Security_Invest | Security investment amount |
# | Security_Breach_Att | Number of security breach attempts |
# | Succ_Sec_Breaches | Number of successful security breaches |
# | Sec_Rating | Overall security rating (High/Medium/Low) |
# | CEO_Sec_Exp | CEO's level of security experience (High/Medium/Low) |
# | LOT_in_Business | Length of time in business (years) |
# | Stock_Market | Whether the company is listed on the stock market (Yes/No) |
#
# ---
#
# ## Algorithms Applied
# | # | Algorithm |
# |---|-----------|
# | 41 | Linear Regression |
# | 42 | Multiple Linear Regression |
# | 43 | Binary Logistic Regression |
# | 44 | Multiple Class Logistic Regression |
# | 45 | kNN (k = 1) |
# | 46 | kNN (k = 5) |
# | 47 | kNN (k = 10) |
# | 48 | kNN (k = 15) |
# | 49 | Decision Tree |
# | 50 | Random Forests |
#
# ---
# ## Objective - predict the security rating of low medium high
#
# ---
#
# ## Data Analysis Plan
#
# 1. **EDA** — Understand structure, summary statistics, and distributions
# 2. **Data Cleaning** — Check and handle missing/null values
# 3. **Outlier Treatment** — Identify and impute outliers (median/mean)
# 4. **Data Types** — Evaluate and encode categorical features
# 5. **Normality Check** — Assess feature distributions to inform model choice
# 6. **Feature Scaling** — Apply standardization/normalization
# 7. **Correlation Analysis** — Remove highly correlated variables; replace with a single derived feature
# 8. **Train-Test Split** — Split dataset before any feature engineering
# 9. **Feature Engineering** — Apply transformations to both train and test sets
# 10. **Modelling** — Fit model, predict, and evaluate using confusion matrix, 0.5 threshold, or MSE

# %%
import pandas as pd
security_df = pd.read_csv("security_data_10000.csv")

print (security_df.head())
# Out:
#         Sector CEO_Gender   Size  Security_Invest  Security_Breach_Att  \
# 0  Hospitality       Male  Large              186                   80
# 1  Hospitality     Female  Large              229                   72
# 2  Hospitality       Male  Small              108                   78
# 3  Hospitality       Male  Large              210                   70
# 4      Banking       Male  Small               34                   19
#
#    Succ_Sec_Breaches Sec_Rating CEO_Sec_Exp  LOT_in_Business Stock_Market
# 0                 38       High        High               11           No
# 1                 42     Medium      Medium               21          Yes
# 2                 35       High      Medium               15          Yes
# 3                 35     Medium         Low               14           No
# 4                  3        Low        High                3           No

# %%
from sklearn.model_selection import train_test_split

security_df_train, security_df_test = train_test_split(security_df, test_size=0.2, random_state=42)

# %% [markdown]
# ## Impute (numeric variables)

# %% [markdown]
# ## Encode categorical variables

# %% [markdown]
# ## Scale
